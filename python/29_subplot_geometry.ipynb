# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.pylabtools import figsize

# indices start at 1 !
plt.subplot(2, 2, 1)
plt.plot(np.random.randn(10))

plt.subplot(2, 2, 4)
plt.plot(np.random.randn(10))

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 3))

x = np.arange(10)
axs[0].plot(x, x**2, 'b')
axs[0].plot(x, x, 'k')

axs[1].plot(x, np.sqrt(x), 'r')

# %%
fig, axs = plt.subplots(2, 2)

axs[0, 0].plot(np.random.randn(4, 4))
axs[0, 1].plot(np.random.randn(4, 4))
axs[1, 0].plot(np.random.randn(4, 4))
axs[1, 1].plot(np.random.randn(4, 4))

plt.tight_layout()
plt.show()

# %%
# Exercise: create a 3 x 3 subplot geometry

fig, axs = plt.subplots(3, 3)
plt.tight_layout()
for ax in axs.flatten():
    ax.plot(np.random.randn(5, 2))
